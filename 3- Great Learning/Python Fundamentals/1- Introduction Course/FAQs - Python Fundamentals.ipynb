# %% [markdown]
# # 🐍 Python Fundamentals — Q&A Pack (Colab‑Ready)
#
# Welcome! This notebook organizes common Python questions into clean, readable sections with examples you can run.
#
# [![Open In Colab](https://colab.research.googleusercontent.com/assets/colab-badge.svg)](https://colab.research.google.com/#fileId=LOCAL_UPLOAD)
#
# **What you get:**
# - ✅ Clean Q&A with tags and emojis
# - ✅ Runnable code cells with comments
# - ✅ Short, correct explanations
# - ✅ Works great on Google Colab

# %% [markdown]
# ## 🧭 Table of Contents
#
# 1. 🔤 Case Sensitivity
# 2. 💬 Comments in Python
# 3. ⚖️ Comparison Operators
# 4. 📦 List vs Tuple vs Set vs Dict
# 5. 🧱 Brackets in Python
# 6. 🔎 Indexing
# 7. 🧮 int32 vs int64
# 8. 🧩 `format()` Placeholders (and f-strings)
# 9. 🛑 `break` vs `continue`
# 10. 🔁 Loop variable `i`
# 11. 🧵 String `SyntaxError`
# 12. 🏷️ `NameError` basics
# 13. ⌨️ `input()`

# %%
# 🚀 Setup (optional)
# Print environment info. In Colab you may optionally install packages via pip.
import sys, platform
print("Python:", sys.version)
print("Platform:", platform.platform())
# Example: uncomment to install extras
# !pip install --quiet numpy

# %% [markdown]
# ## 1) 🔤 Is Python case sensitive?
# **Tags:** `#python` `#casesensitive`
#
# ✅ Yes — Python is **case-sensitive**. Identifiers like `HelloWorld`, `helloworld`, and `HELLOWORLD` are all different.

# %%
# Different names -> different variables
hello = 1
Hello = 2
HELLO = 3
print("hello:", hello, "| Hello:", Hello, "| HELLO:", HELLO)

# %% [markdown]
# ## 2) 💬 How do I write comments in Python?
# **Tags:** `#comments` `#python`
#
# Use `#` for single-line comments. Triple quotes (`'''` or `"""`) are string literals commonly used as **docstrings** or block notes.

# %%
# Single-line
x = 42  # inline comment

'''
This is a string literal that can act as a block note.
Use proper docstrings at module/function/class level.
'''

def area(w, h):
    """Return the area of a rectangle (w * h)."""
    return w * h

# %% [markdown]
# ## 3) ⚖️ What are the comparison operators in Python?
# **Tags:** `#python` `#comparisonoperators`
#
# These return booleans (`True`/`False`). With `a = 5` and `b = 6`:
#
# | Operator | Description | Example | Result |
# |---|---|---|---|
# | `==` | equal to | `a == b` | `False` |
# | `!=` | not equal to | `a != b` | `True` |
# | `>`  | greater than | `a > b`  | `False` |
# | `>=` | greater or equal | `a >= b` | `False` |
# | `<`  | less than | `a < b`  | `True` |
# | `<=` | less or equal | `a <= b` | `True` |

# %%
a, b = 5, 6
print("a == b:", a == b)
print("a != b:", a != b)
print("a  > b:", a > b)
print("a >= b:", a >= b)
print("a  < b:", a < b)
print("a <= b:", a <= b)

# %% [markdown]
# ## 4) 📦 What’s the difference between list, tuple, set, and dict?
# **Tags:** `#difference` `#list` `#tuple` `#set` `#dictionary`
#
# | Type | Description | Mutable | Indexed | Example |
# |------|--------------|--------|--------|--------|
# | **List `[]`** | Ordered collection | ✅ | ✅ | `['a', 2, True, 'b']` |
# | **Tuple `()`** | Ordered, **immutable** | ❌ | ✅ | `('a', 2, True, 'b')` |
# | **Set `{}` or `set([...])`** | **Unordered**, unique items | ✅ | ❌ | `{'a', 2, True, 'b'}` |
# | **Dict `{k: v}`** | Key→Value mapping | ✅ | ✅ (by key) | `{1: 'Jan', 2: 'Feb'}` |

# %%
lst = ["a", 2, True, "b"]
tup = ("a", 2, True, "b")
st  = {"a", "a", 2, True, "b"}   # duplicates removed
dct = {1:'Jan', 2:'Feb', 3:'Mar'}

print("list:", lst)
print("tuple:", tup)
print("set:", st)
print("dict:", dct)

print("lst[1] ->", lst[1])
print("tup[1] ->", tup[1])
print("dct[2] ->", dct[2])
print("2 in set? ->", 2 in st)

# %% [markdown]
# ## 5) 🧱 What do different kinds of brackets do in Python?
# **Tags:** `#brackets` `#python`
#
# - **Parentheses `()`**: function calls, grouping, tuples
# - **Square brackets `[]`**: lists, indexing/slicing, list comprehensions
# - **Curly braces `{}`**: dicts and sets

# %% [markdown]
# ## 6) 🔎 What is indexing?
# **Tags:** `#indexing` `#list` `#tuple`
#
# Indexing retrieves elements by position (0-based) or by key for dicts. Sets do **not** support indexing.

# %%
lst = [1,2,4,5]
dct = {'one': 1, 'two': 2, 'three': 3}
tup = (1,2,3,4,5)

print(lst[1])      # 2
print(dct['two'])  # 2
print(tup[1])      # 2

# %% [markdown]
# ## 7) 🧮 What do 32 and 64 mean in `int32` and `int64`?
# **Tags:** `#int32` `#int64`
#
# - In NumPy: `int32` → 32 bits (4 bytes), `int64` → 64 bits (8 bytes).
#   - Signed ranges (approx.):
#     - `int32`: −2,147,483,648 … 2,147,483,647
#     - `int64`: −9,223,372,036,854,775,808 … 9,223,372,036,854,775,807
# - Pure Python `int` is arbitrary‑precision (no fixed bit width).

# %%
# Pure Python 'int' grows as needed
big = 10**200
print("Digits in big:", len(str(big)))

# NumPy demo (optional)
# import numpy as np
# a = np.int32(123); b = np.int64(123)
# print(a, a.dtype, a.nbytes, "bytes")
# print(b, b.dtype, b.nbytes, "bytes")

# %% [markdown]
# ## 8) 🧩 Why curly braces in `format()`?
# **Tags:** `#print` `#bracket` `#variable`
#
# Curly braces `{}` are placeholders for arguments given to `str.format`. Modern Python often prefers **f-strings**.

# %%
one, two = "Hello", "Data"
print("{} {}".format(one, two))   # format
print(f"{one} {two}")             # f-string (preferred)

n, i = 3, 7
print("{} * {} = {}".format(n, i, n*i))
print(f"{n} * {i} = {n*i}")

# %% [markdown]
# ## 9) 🛑 How to exit/skip within loops? (`break` / `continue`)
# **Tags:** `#forloop` `#exit` `#looping` `#concept`
#
# - `break`: stop the loop entirely
# - `continue`: skip to the next iteration

# %%
# break example
for ch in "GreatLearning":
    if ch == "L":
        break
    print(ch)
print("The End (after break)")

print("-"*20)

# continue example
for ch in "GreatLearning":
    if ch == "L":
        continue
    print(ch)
print("The End (after continue)")

# %% [markdown]
# ## 10) 🔁 What is the purpose of `i` in loops?
# **Tags:** `#looping` `#forloop`
#
# `i` is a conventional loop variable name (you can use any valid name).

# %%
for i in range(5, 21, 5):
    print("i =", i)

# %% [markdown]
# ## 11) 🧵 Why a `SyntaxError` when defining a string?
# **Tags:** `#Error` `#String` `#code`
#
# Strings must be quoted.

# %%
a = "Great Learning"   # correct
print(a)

# a = Great Learning   # SyntaxError (missing quotes)

# %% [markdown]
# ## 12) 🏷️ Why a `NameError` when printing a variable?
# **Tags:** `#error` `#code` `#nameerror`
#
# Happens when a name isn’t defined in the current scope. Define it first (or run the defining cell first).

# %%
attributes = {
    'Brand':'Apple',
    'RAM (GB)':4,
    'Storage (GB)':128,
    'Price ($)':800
}
print(attributes)

# %% [markdown]
# ## 13) ⌨️ What does `input()` do?
# **Tags:** `#input` `#nooutput`
#
# `input()` pauses and waits for user text, then returns it as a string.

# %%
# Uncomment to try interactively in a notebook/Colab:
# name = input("Enter your name: ")
# print(f"Hello, {name}!")

# %% [markdown]
# ---
#
# ## ✅ Wrap-Up & Next Steps
#
# - Tweak examples and add your own practice snippets.
# - Try small variations (e.g., change ranges, add keys, test comparisons).
# - For quick navigation, use Find (`Ctrl/Cmd + F`) on section titles.
#
# Happy coding! 🎉
